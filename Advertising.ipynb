# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('advertising.csv')
data.describe()
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1000.000000  1000.000000   1000.000000
# mean                  65.000200    36.009000  55000.000080
# std                   15.853615     8.785562  13414.634022
# min                   32.600000    19.000000  13996.500000
# 25%                   51.360000    29.000000  47031.802500
# 50%                   68.215000    35.000000  57012.300000
# 75%                   78.547500    42.000000  65470.635000
# max                   91.430000    61.000000  79484.800000
#
#        Daily Internet Usage         Male  Clicked on Ad
# count           1000.000000  1000.000000     1000.00000
# mean             180.000100     0.481000        0.50000
# std               43.902339     0.499889        0.50025
# min              104.780000     0.000000        0.00000
# 25%              138.830000     0.000000        0.00000
# 50%              183.130000     0.000000        0.50000
# 75%              218.792500     1.000000        1.00000
# max              269.960000     1.000000        1.00000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.2+ KB

# %%
data.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad
# 0   2016-03-27 0:53:11              0
# 1   2016-04-04 1:39:02              0
# 2  2016-03-13 20:35:42              0
# 3   2016-01-10 2:31:19              0
# 4   2016-06-03 3:36:18              0

# %%
data.City.value_counts()
# Out:
# Williamsport    3
# Lisamouth       3
# Pamelamouth     2
# Port Juan       2
# Robertfurt      2
#                ..
# West Ricardo    1
# Campbellstad    1
# West Alyssa     1
# Odomville       1
# Dianashire      1
# Name: City, Length: 969, dtype: int64

# %%
import seaborn as sns
sns.countplot(data.City)
# Out:
# C:\Users\Prathek\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='City', ylabel='count'>

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
sns.countplot(x = data.Country)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='count'>

# %%
data.Country.value_counts().describe()
# Out:
# count    237.000000
# mean       4.219409
# std        1.837222
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        6.000000
# max        9.000000
# Name: Country, dtype: float64

# %%
data.Timestamp.dtype
# Out:
# dtype('O')

# %%
dates = pd.to_datetime(data.Timestamp)

# %%
def hour(time):
    return time.hour
data['hour'] = dates.apply(hour)
# data.Timestamp.apply(lambda x:x.hour)

# %%
data.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad  hour
# 0   2016-03-27 0:53:11              0     0
# 1   2016-04-04 1:39:02              0     1
# 2  2016-03-13 20:35:42              0    20
# 3   2016-01-10 2:31:19              0     2
# 4   2016-06-03 3:36:18              0     3

# %%
data['min'] = dates.apply(lambda x:x.minute)

# %%
data.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad  hour  min
# 0   2016-03-27 0:53:11              0     0   53
# 1   2016-04-04 1:39:02              0     1   39
# 2  2016-03-13 20:35:42              0    20   35
# 3   2016-01-10 2:31:19              0     2   31
# 4   2016-06-03 3:36:18              0     3   36

# %%
X = data.drop(['Clicked on Ad', 'City', 'Ad Topic Line', 'Timestamp'],axis=1)
y = data['Clicked on Ad']

# %%
X
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male  \
# 0                       68.95   35     61833.90                256.09     0
# 1                       80.23   31     68441.85                193.77     1
# 2                       69.47   26     59785.94                236.50     0
# 3                       74.15   29     54806.18                245.89     1
# 4                       68.37   35     73889.99                225.58     0
# ..                        ...  ...          ...                   ...   ...
# 995                     72.97   30     71384.57                208.58     1
# 996                     51.30   45     67782.17                134.42     1
# 997                     51.63   51     42415.72                120.37     1
# 998                     55.55   19     41920.79                187.95     0
# 999                     45.01   26     29875.80                178.35     0
#
#                     Country  hour  min
# 0                   Tunisia     0   53
# 1                     Nauru     1   39
# 2                San Marino    20   35
# 3                     Italy     2   31
# 4                   Iceland     3   36
# ..                      ...   ...  ...
# 995                 Lebanon    21   49
# 996  Bosnia and Herzegovina     2    7
# 997                Mongolia    17   24
# 998               Guatemala     2   35
# 999                  Brazil    21   43
#
# [1000 rows x 8 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 995    1
# 996    1
# 997    1
# 998    0
# 999    1
# Name: Clicked on Ad, Length: 1000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train.iloc[:, :4] = sc.fit_transform(X_train.iloc[:, :4])
X_test.iloc[:, :4] = sc.transform(X_test.iloc[:, :4])
X_train.iloc[:, 6:] = sc.fit_transform(X_train.iloc[:, 6:])
X_test.iloc[:, 6:] = sc.transform(X_test.iloc[:, 6:])
# Out:
# C:\Users\Prathek\anaconda3\lib\site-packages\pandas\core\indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# C:\Users\Prathek\anaconda3\lib\site-packages\pandas\core\indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# C:\Users\Prathek\anaconda3\lib\site-packages\pandas\core\indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# C:\Users\Prathek\anaconda3\lib\site-packages\pandas\core\indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
X_train
# Out:
#      Daily Time Spent on Site       Age  Area Income  Daily Internet Usage  \
# 727                  1.018164 -0.709133     0.172072              1.163825
# 963                 -0.270791  0.646978     1.106086              1.506423
# 295                  1.095805 -0.031078     0.881036              0.871011
# 36                  -0.175477  1.890079     0.140504             -1.245221
# 805                  1.189857 -0.935151     0.394251              0.009085
# ..                        ...       ...          ...                   ...
# 338                  0.589565  0.420959     1.421553              0.895450
# 851                 -1.889244 -0.144087    -0.537558             -0.507979
# 633                 -1.568584  0.081932     0.035674             -0.984086
# 935                  1.195538 -0.031078     0.996955              0.320003
# 941                  0.866040  1.664061     0.898530             -0.417012
#
#      Male                               Country      hour       min
# 727     1  United States Minor Outlying Islands -0.684041 -1.702447
# 963     1                                Guyana  0.182291 -0.192387
# 295     1                             Macedonia -1.261595 -1.295892
# 36      1                            Montenegro  0.471068 -0.657021
# 805     1                             Hong Kong  0.037902 -0.540863
# ..    ...                                   ...       ...       ...
# 338     1                             Indonesia  0.182291  1.201514
# 851     1                              Anguilla  0.182291 -1.295892
# 633     0                                France -1.405984  1.259593
# 935     0                              Zimbabwe -1.694761  0.853038
# 941     0                                 Ghana -1.117207 -1.470130
#
# [800 rows x 8 columns]

# %%
X_test
# Out:
#      Daily Time Spent on Site       Age  Area Income  Daily Internet Usage  \
# 927                  1.648124  0.194941    -1.339744              0.101863
# 144                  0.255017  0.533969     1.676626              0.681609
# 947                 -1.665792 -0.596124    -0.227619             -0.581749
# 665                 -0.441221 -0.483114    -2.895590              0.340821
# 520                 -1.163339  0.646978     0.815111             -1.002415
# ..                        ...       ...          ...                   ...
# 319                 -0.188101  0.872996    -0.794754             -1.707976
# 868                  0.168539 -1.274179     0.634957              1.024659
# 936                 -0.117404  0.986006    -1.163225             -1.641901
# 357                 -0.959454  0.307950    -0.674011             -1.558854
# 664                  1.030789 -0.370105     0.856340              0.782080
#
#      Male                   Country      hour       min
# 927     0                    Cyprus -0.684041 -1.470130
# 144     0  Turks and Caicos Islands -1.550372  0.562642
# 947     1                   Iceland -0.395264  1.201514
# 665     1                Tajikistan -0.250875  0.562642
# 520     0                  Ethiopia  1.193011 -0.715100
# ..    ...                       ...       ...       ...
# 319     0                   Austria  0.326679 -1.644368
# 868     1                   Armenia -1.405984  1.491910
# 936     0                   Georgia  0.037902 -1.528209
# 357     0                     Samoa -0.684041 -0.482783
# 664     0                   Vietnam -1.550372 -0.540863
#
# [200 rows x 8 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X_train.Country = np.array(le.fit_transform(X_train.Country))
# Out:
# C:\Users\Prathek\anaconda3\lib\site-packages\pandas\core\generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X_test.Country = np.array(le.fit_transform(X_test.Country))
# Out:
# C:\Users\Prathek\anaconda3\lib\site-packages\pandas\core\generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
X_train
# Out:
#      Daily Time Spent on Site       Age  Area Income  Daily Internet Usage  \
# 727                  1.018164 -0.709133     0.172072              1.163825
# 963                 -0.270791  0.646978     1.106086              1.506423
# 295                  1.095805 -0.031078     0.881036              0.871011
# 36                  -0.175477  1.890079     0.140504             -1.245221
# 805                  1.189857 -0.935151     0.394251              0.009085
# ..                        ...       ...          ...                   ...
# 338                  0.589565  0.420959     1.421553              0.895450
# 851                 -1.889244 -0.144087    -0.537558             -0.507979
# 633                 -1.568584  0.081932     0.035674             -0.984086
# 935                  1.195538 -0.031078     0.996955              0.320003
# 941                  0.866040  1.664061     0.898530             -0.417012
#
#      Male  Country      hour       min
# 727     1      221 -0.684041 -1.702447
# 963     1       89  0.182291 -0.192387
# 295     1      123 -1.261595 -1.295892
# 36      1      140  0.471068 -0.657021
# 805     1       94  0.037902 -0.540863
# ..    ...      ...       ...       ...
# 338     1       98  0.182291  1.201514
# 851     1        6  0.182291 -1.295892
# 633     0       70 -1.405984  1.259593
# 935     0      233 -1.694761  0.853038
# 941     0       78 -1.117207 -1.470130
#
# [800 rows x 8 columns]

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[101   1]
#  [  4  94]]
# 0.975

# %%
data.corr()
# Out:
#                           Daily Time Spent on Site       Age  Area Income  \
# Daily Time Spent on Site                  1.000000 -0.331513     0.310954
# Age                                      -0.331513  1.000000    -0.182605
# Area Income                               0.310954 -0.182605     1.000000
# Daily Internet Usage                      0.518658 -0.367209     0.337496
# Male                                     -0.018951 -0.021044     0.001322
# Clicked on Ad                            -0.748117  0.492531    -0.476255
# hour                                      0.000895 -0.049905     0.034573
# min                                      -0.021815 -0.030467     0.001158
#
#                           Daily Internet Usage      Male  Clicked on Ad  \
# Daily Time Spent on Site              0.518658 -0.018951      -0.748117
# Age                                  -0.367209 -0.021044       0.492531
# Area Income                           0.337496  0.001322      -0.476255
# Daily Internet Usage                  1.000000  0.028012      -0.786539
# Male                                  0.028012  1.000000      -0.038027
# Clicked on Ad                        -0.786539 -0.038027       1.000000
# hour                                  0.074347  0.058552      -0.047431
# min                                   0.010605  0.057700       0.022969
#
#                               hour       min
# Daily Time Spent on Site  0.000895 -0.021815
# Age                      -0.049905 -0.030467
# Area Income               0.034573  0.001158
# Daily Internet Usage      0.074347  0.010605
# Male                      0.058552  0.057700
# Clicked on Ad            -0.047431  0.022969
# hour                      1.000000 -0.021106
# min                      -0.021106  1.000000
